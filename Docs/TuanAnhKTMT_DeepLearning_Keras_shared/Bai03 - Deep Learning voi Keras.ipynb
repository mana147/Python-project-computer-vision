# %% [markdown]
# # Các lệnh hay dùng

# %% [raw]
# esc: về chế độ commmand
# enter: vào chế độ soạn thảo
#
# Ctrl-Shift-Minus: chia cell
# shift_m:          gộp cell
#
# a: chèn cell bên trên cell hiện tại
# b: Chèn cell bên dưới cell hiện tại
#
# dd: xoá cell đang chọn
# m:  Đánh dấu cell thành Markdown

# %% [markdown]
# # Chương trình:

# %% [raw]
# Đề bài:
# Cho phương trình y=wx+b   (y=ax+b)
# - Cho nghiệm x=[x1,x2,....,xn] , y=[y1,y2,...,yn]
# - tìm w (weight)
# - (b: bias)

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]='-1' # ép training trên CPU 
from keras.layers import *
from keras.models import *
from keras import optimizers

# %%
x=[1, 2, 3, 4] #  5            12
y=[2, 4, 6, 8] #  ~10          24
x, y           #  3.3243427
               #  9.908858                 #
# Out:
# ([1, 2, 3, 4], [2, 4, 6, 8])

# %%
model=Sequential([
    Dense(1, input_shape=(1,))
])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
sgd=optimizers.SGD(lr=0.001)
model.compile(loss='mse',optimizer=sgd)

# %%
model.fit(x,y,epochs=500)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 0s 24ms/step - loss: 28.6516
# Epoch 2/500
# 4/4 [==============================] - 0s 235us/step - loss: 27.7045
# Epoch 3/500
# 4/4 [==============================] - 0s 537us/step - loss: 26.7888
# Epoch 4/500
# 4/4 [==============================] - 0s 627us/step - loss: 25.9034
# Epoch 5/500
# 4/4 [==============================] - 0s 330us/step - loss: 25.0474
# Epoch 6/500
# 4/4 [==============================] - 0s 587us/step - loss: 24.2197
# Epoch 7/500
# 4/4 [==============================] - 0s 482us/step - loss: 23.4194
# Epoch 8/500
# 4/4 [==============================] - 0s 473us/step - loss: 22.6456
# Epoch 9/500
# 4/4 [==============================] - 0s 231us/step - loss: 21.8974
# Epoch 10/500
# 4/4 [==============================] - 0s 339us/step - loss: 21.1741
# Epoch 11/500
# 4/4 [==============================] - 0s 296us/step - loss: 20.4746
# Epoch 12/500
# ...

# %%
y_pred=model.predict([12.])
y_pred
# Out:
# array([[22.414452]], dtype=float32)

# %%
y_pred=model.predict([5.])
y_pred
# Out:
# array([[9.638527]], dtype=float32)

# %% [markdown]
# [activations](../activations.md)
