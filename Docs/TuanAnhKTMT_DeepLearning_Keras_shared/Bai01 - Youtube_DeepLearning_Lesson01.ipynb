# %% [markdown]
# # Introduce to Deep Learning

# %% [markdown]
# ## Introduce to Deep Learning

# %% [markdown]
# __Artificial neural networks (ANNs)__ or connectionist systems are computing systems vaguely inspired by the biological neural networks that constitute animal brains. Such systems "learn" to perform tasks by considering examples, generally without being programmed with any task-specific rules

# %% [markdown]
# <img src="img/coban.png" style="width:300px">

# %% [markdown]
# <img src="img/07.png" style="height:400px;width:600px">

# %% [markdown]
# <img src="img/08.jpeg" style="height:400px;width:600px">

# %% [markdown]
# <img src="img/02.jpg" style="height:400px;width:600px">

# %% [markdown]
# <img src="img/04.png" style="heigh:400px;width:600px">

# %%
from IPython.display import Image
Image("img/09.jpg")

# %% [markdown]
# ## Keras programming for Deep Learning

# %% [markdown]
# More detail in: https://keras.io/

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
model=Sequential([
    Dense(4, input_shape=(3,)),
    Dense(2)
])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_10 (Dense)             (None, 4)                 16
# _________________________________________________________________
# dense_11 (Dense)             (None, 2)                 10
# ...
# Total params: 26.0
# Trainable params: 26
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# <img src="img/coban.png" style="height:300px">

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation
model=Sequential([
    Dense(4, input_shape=(3,), activation='relu'),
    Dense(2,activation='softmax')
])

# %% [markdown]
# ## Learning Cources:

# %% [markdown]
# ### Cource in English:

# %% [markdown]
# https://keras.io/

# %% [markdown]
# Machine Learning với thầy Andrew Ng trên Coursera: https://www.coursera.org/learn/machine-learning

# %% [markdown]
# Deep Learning by Google trên Udacity: https://www.udacity.com/course/deep-learning--ud730

# %% [markdown]
# Machine Learning mastery: http://machinelearningmastery.com/

# %% [markdown]
# ### Các kiến thức tiếng Việt:

# %% [markdown]
# Search Google/Youtube: "Tuananhktmt", "Tuananhktmt: Deep-keras"
# "Deeperas" (Deeperas=Deep Learning + Keras), picat

# %% [markdown]
# http://viet.jnlp.org/kien-thuc-co-ban-ve-xu-ly-ngon-ngu-tu-nhien/machine-learning-trong-nlp

# %% [markdown]
# https://ongxuanhong.wordpress.com/

# %% [markdown]
# https://ml-book-vn.khanhxnguyen.com/

# %%
from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))

# %%
from IPython.display import Image
Image("img/coban.png")

# %%
# !geany ~/anaconda3/envs/P3/lib/python3.6/site-packages/keras/models.py

# %%
# ?model.fit
